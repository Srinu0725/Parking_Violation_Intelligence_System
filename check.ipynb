# %%
import pandas as pd

# %%
df = pd.read_csv("data/parking_violations.csv")

df.to_parquet(
    "data/parking_violations.parquet",
    compression="snappy"
)

# %%
check["description"].unique()
# Out:
# array([nan])
