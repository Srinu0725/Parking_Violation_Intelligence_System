# %%
import pandas as pd

# %%
df = pd.read_parquet(r"data/profiles.parquet")

# %%
df.columns
# Out:
# Index(['cluster', 'violation_count', 'centroid_lat', 'centroid_lon', 'lat_std',
#        'lon_std', 'top_violation', 'top_vehicle', 'top_junction',
#        'top_station', 'peak_ratio', 'weekend_ratio', 'avg_vehicle_weight',
#        'avg_severity', 'avg_response_lag', 'scooter_ratio', 'car_ratio',
#        'heavy_ratio', 'unique_vehicles', 'unique_devices', 'radius_m',
#        'cis_score', 'recommended_shift', 'priority_rank'],
#       dtype='object')

# %%
check["description"].unique()
# Out:
# array([nan])
